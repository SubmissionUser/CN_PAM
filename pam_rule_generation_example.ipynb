# %% [markdown]
# # Rule Generation

# %% [markdown]
# In this notebook we will showcase the efficiency of PAM for rule generation.
#
# We will follow the procedure described in Section 3.4 for the applicaiton of rule generation.
#
# The process is simple:
# 1. First download the **YAGO3-10** dataset. The .tsv with the triples is expected to be in folder in the same directory as this notebook with the name "data".
# 2. Create the **lossless** $1$-hop PAM  and the **k-hop** PAMs $P^k$ which hold the corresponding paths.
# 3. Find paths $Path^k$ that may imply a head relation $r_H$ through a simple check: $P[A,B] = r_H$ and $P^k[A,B] = Path^k \neq 0$.

# %% [markdown]
# ## Initial imports

# %%
import tqdm
import time
import string

import pandas as pd
import numpy as np

from itertools import permutations, product
from pam_creation import create_pam_matrices
from utils import load_data, get_primefactors

# %% [markdown]
# # Loading the data
#
# We simply read the collection of triples in a dataframe

# %%
path_to_files = './data/YAGO3-10'
project = "YAGO3-10"


time_s = time.time()
_, df_train, _, _, _ = load_data(path_to_files, project)

unique_rels = sorted(list(df_train['rel'].unique()))
unique_nodes = sorted(set(df_train['head'].values.tolist() + df_train['tail'].values.tolist()))
print(f'# of unique rels: {len(unique_rels)} \t | # of unique nodes: {len(unique_nodes)}')


time_prev = time.time()
time_needed = time_prev - time_s
print(f'Total time: {time_needed:.5f} secs ({time_needed/60:.2f} mins)')
# Out:
# Total: 735915 triples in train + eval!)
# In train: 732556
# In valid: 3359
# In test: 3390
# # of unique rels: 36 	 | # of unique nodes: 122780
# Total time: 0.91459 secs (0.02 mins)

# %%
df_train.head()
# Out:
#              head             rel                       tail
# 0          Chatou     isLocatedIn                     France
# 1   Toni_Kuivasto  isAffiliatedTo  Helsingin_Jalkapalloklubi
# 2  Albrecht_Dürer          diedIn                  Nuremberg
# 3  Edwin_Holliday  isAffiliatedTo       Hereford_United_F.C.
# 4  William_Hopper         actedIn   The_Bad_Seed_(1956_film)

# %% [markdown]
# ## Create the $1$-hop **lossless** PAM and its powers.
#
# Here we limit $k=3$.

# %%
max_k = 3
pam_1hop_lossless, pam_powers, node2id, rel2id = create_pam_matrices(df_train, 
                                                                     max_order=max_k, 
                                                                     spacing_strategy='step_100', 
                                                                     use_log=False)
# Out:
# # of unique rels: 36 	 | # of unique nodes: 122780
# (122780, 122780) Sparsity: 100.00 %
# Sparsity 2-hop: 99.97 %
# Sparsity 3-hop: 99.84 %

# %% [markdown]
# # Generate possible rules
#
# The procedure is as follows:
# 1. We first find all pairs of $(i,j)$ for which $P[i,j] = r_H = \neq 0 $.
# 2. Then we keep track of all the different values for these $(i,j)$,that $P^k[i,j] =  Path^k = \neq 0$.
# 3. We aggregate all of these rules in a DataFrame, keeping also frequencies and other characteristics of the rules (e.g. support, confidence etc.)

# %% [markdown]
# ## 1-hop rules
#
# Rules that have only one atom in the body.
# E.g. $knows(A,B)->friend(A,B)$

# %%
all_rules = []
cur_power = pam_1hop_lossless
rows, cols = pam_1hop_lossless.nonzero()
head_rels = np.array(pam_1hop_lossless[rows,cols]).flatten()
cur_rules = []

time_s = time.time()

# Iterate over all non-zero # P[i,j]
for index_nonzero, body_rel in tqdm.tqdm_notebook(enumerate(head_rels.flatten()), total=len(head_rels)):
    head_rels_cur = get_primefactors(body_rel)
    if len(head_rels_cur) > 1 :
        # Subrelation rules
        for comb in permutations(head_rels_cur, 2):
            if comb[0] in rel2id.values():
                cur_rules.append(
                    {
                        'head_rel':comb[0], 
                        "body":comb[1], 
                        "hop":1, 
                        'type':'same_cell',
                        'row': rows[index_nonzero],
                        'col': cols[index_nonzero]
                     }
                )

# Keep all rules
df_rules = pd.DataFrame(cur_rules)
# Aggregate the patterns by their body value
grouped_by_head_and_body = df_rules.groupby(["head_rel", 'type'])['body'].value_counts().to_dict()
# Calculate the support of the heads
head_support = df_rules['head_rel'].value_counts().to_dict()



all_bodies = []
for value in cur_power.data:
    all_bodies.extend(get_primefactors(value))
# Calculate the support of the bodies
body_support = pd.Series(all_bodies).value_counts().to_dict()

for key in grouped_by_head_and_body:
    head_rel, type_, body_rel  = key
    all_rules.append({
        "head_rel": head_rel, 
        'body':body_rel, 
        'head_body_count':grouped_by_head_and_body[key], 
        'body_count':body_support[body_rel],
        'head_count':head_support[head_rel],
        'hop':1, 
        'type':type_})

print(f'Total # rules: {len(all_rules)}')

time_prev = time.time()
time_needed = time_s - time_s
print(f'Total time: {time_needed:.5f} secs ({time_needed/60:.2f} mins)')
# Out:
# /tmp/ipykernel_2379803/3213398325.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index_nonzero, body_rel in tqdm.tqdm_notebook(enumerate(head_rels.flatten()), total=len(head_rels)):
#   0%|          | 0/725199 [00:00<?, ?it/s]
# Total # rules: 104
# Total time: 0.00000 secs (0.00 mins)

# %% [markdown]
# ## $k-$hop rules
#
# Rules of the form:
# $r1(A,B) \wedge r2(B,C) \wedge ... rk(Y,Z) - > r_H(A,Z)$

# %%
max_hop = len(pam_powers)
laplace_smoothing_alpha = 0

time_s = time.time()

rows, cols = pam_1hop_lossless.nonzero()
head_rels = np.array(pam_1hop_lossless[rows,cols]).flatten()
for cur_hop in range(1,max_hop):
    cur_power = pam_powers[cur_hop]
    cur_rules = []
    for index_nonzero, body_rel in enumerate(np.array(cur_power[rows, cols]).flatten()):
        cur_prime_factors = get_primefactors(head_rels[index_nonzero])
        if body_rel != 0:
            for head_rel in cur_prime_factors:
                if head_rel in rel2id.values():
                    cur_rules.append(
                        {
                            'head_rel':head_rel, 
                            "body":body_rel, 
                            "hop":cur_hop + 1, 
                            'type':'same_cell',
                            'row': rows[index_nonzero],
                            'col': cols[index_nonzero]
                        }
                    )
                
    df_rules = pd.DataFrame(cur_rules)
    grouped_by_head_and_body = df_rules.groupby(["head_rel", 'type'])['body'].value_counts().to_dict()
    head_support = df_rules['head_rel'].value_counts().to_dict()
    body_support = pd.Series(cur_power.data).value_counts().to_dict()
    for key in grouped_by_head_and_body:
        head_value, type_, body_value  = key
        all_rules.append({
            "head_rel": head_value, 
            'body':body_value, 
            'head_body_count':grouped_by_head_and_body[key], 
            'body_count':body_support[body_value],
            'head_count':head_support[head_value],
            'hop':cur_hop + 1,
            'type':type_})

    print(f'{cur_hop + 1}-hop level rules: {len(grouped_by_head_and_body)}')
print(f'Total # rules: {len(all_rules)}')

time_prev = time.time()
time_needed = time_prev - time_s
print(f'Total time: {time_needed:.5f} secs ({time_needed/60:.2f} mins)')


all_rules_df = pd.DataFrame(all_rules)
all_rules_df['conf'] = all_rules_df['head_body_count'] / (all_rules_df['body_count'] + laplace_smoothing_alpha)
all_rules_df['head_coverage'] = all_rules_df['head_body_count'] / (all_rules_df['head_count'])
all_rules_df['score'] = 2*(all_rules_df['conf']*all_rules_df['head_coverage']/(all_rules_df['head_coverage'] + all_rules_df['conf'] ))

all_rules_df['body_head_str'] = all_rules_df['body'].astype(str) + "_" + all_rules_df['head_rel'].astype(str)
all_rules_df.sort_values(['score'], ascending=False)
# Out:
# 2-hop level rules: 4320
# 3-hop level rules: 24015
# Total # rules: 28439
# Total time: 1.64373 secs (0.03 mins)
#        head_rel               body  head_body_count  body_count  head_count  \
# 71         2851               1049              992        2566        1587
# 9902       1049  25500143730021451              619         731        2339
# 1180       2221            2556371              718        2335        1252
# 21132      2953        11743094698                1           1           4
# 865        1361            1566511             1391        2230        5155
# ...         ...                ...              ...         ...         ...
# 7918        839         8068178897                3     3101484        4737
# 15578      2647        33570932693                1     1258733          14
# 205         211            9616423                1     2403292        1011
# 10021      1049         2029065253                1     2618367        2339
# 10036      1049         8068178897                1     3101484        2339
#
#        hop       type          conf  head_coverage         score  \
# 71       1  same_cell  3.865939e-01       0.625079  4.777269e-01
# 9902     3  same_cell  8.467852e-01       0.264643  4.032573e-01
# 1180     2  same_cell  3.074946e-01       0.573482  4.003345e-01
# 21132    3  same_cell  1.000000e+00       0.250000  4.000000e-01
# 865      2  same_cell  6.237668e-01       0.269835  3.767095e-01
# ...    ...        ...           ...            ...           ...
# 7918     3  same_cell  9.672789e-07       0.000633  1.931608e-06
# 15578    3  same_cell  7.944497e-07       0.071429  1.588882e-06
# 205      2  same_cell  4.160959e-07       0.000989  8.318419e-07
# 10021    3  same_cell  3.819174e-07       0.000428  7.631531e-07
# 10036    3  same_cell  3.224263e-07       0.000428  6.443666e-07
#
#                 body_head_str
# 71                  1049_2851
# 9902   25500143730021451_1049
# 1180             2556371_2221
# 21132        11743094698_2953
# 865              1566511_1361
# ...                       ...
# 7918           8068178897_839
# 15578        33570932693_2647
# 205               9616423_211
# 10021         2029065253_1049
# 10036         8068178897_1049
#
# [28439 rows x 11 columns]

# %% [markdown]
# We have generated $28439$ patterns that may imply (with different confidence, support levels) different relations in a matter of seconds.

# %%
id2rel = dict(zip(rel2id.values(), rel2id.keys()))

def generate_rule_string(chain_of_relations:list[str], head_rel:str, type_of_rule:str):
    """Helper function to create the rule

    Args:
        chain_of_relations (list[str]): The chain of relations followed.
        head_rel (str): The relation implied in the head.
        type_of_rule (str): The type of the rule. 'same_cell' or 'symmetric'.
        The difference in the cases is:
        'same_cell': r1(A,B)^r2(B,C)->r3(A,C)
        or
        'symmetric': r1(A,B)^r2(B,C)->r3(C,A)

    Returns:
        str: the rule as a Horn clause
    """

    possible_letters = string.ascii_uppercase
    first_letter = possible_letters[0]
    rule_str = ""
    for i_rel, relation in enumerate(chain_of_relations):
        next_letter = possible_letters[possible_letters.index(first_letter) + 1]
        rule_str += f"{relation}({first_letter}, {next_letter}) ^ "
        first_letter = next_letter

    rule_str = rule_str[:-2]
    
    if type_of_rule == 'same_cell':
        head = f"-> {head_rel}({possible_letters[0]}, {next_letter})"
    else:
        head = f"-> {head_rel}({next_letter}, {possible_letters[0]})"

    rule_str += head
    return rule_str

# %%
num_hops = 2
rules_mapped = []
for i,row in all_rules_df[(all_rules_df['hop']<=num_hops) & (all_rules_df['score']>=0.01)].sort_values(['score'], ascending=False).iterrows():
    try:
        chain = [id2rel[pf] for pf in get_primefactors(row['body'])]
    except KeyError:
        continue
    if len(chain) <= num_hops:
        pass
    
    head_rel = id2rel[row['head_rel']]
    rule_str = generate_rule_string(chain, head_rel, row['type'])
    print(f"{row['score']:.4f} : {rule_str}\t")
    print('Chain:',chain, [pf for pf in get_primefactors(row['body'])])
    print('Predicts:', id2rel[row['head_rel']],[row['head_rel']], f"({row['type']})")
    print()
    rules_mapped.append({'Score': row['score'],'Head Rel':head_rel, 'Rule': rule_str})
rules_df = pd.DataFrame(rules_mapped)
# Out:
# 0.4777 : hasCapital(A, B) -> isLocatedIn(A, B)
# Chain: ['hasCapital'] [1049]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.4003 : hasChild(A, B) ^ isAffiliatedTo(B, C) -> isAffiliatedTo(A, C)
# Chain: ['hasChild', 'isAffiliatedTo'] [1151, 2221]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.3767 : hasChild(A, B) ^ hasGender(B, C) -> hasGender(A, C)
# Chain: ['hasChild', 'hasGender'] [1151, 1361]
# Predicts: hasGender [1361] (same_cell)
#
# 0.3077 : directed(A, B) -> created(A, B)
# Chain: ['directed'] [419]
# Predicts: created [107] (same_cell)
#
# 0.3043 : isLocatedIn(A, B) -> isLocatedIn(A, B)
# Chain: ['isLocatedIn'] [2851]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.3030 : isKnownFor(A, B) -> influences(A, B)
# Chain: ['isKnownFor'] [2647]
# Predicts: influences [2113] (same_cell)
#
# 0.2999 : worksAt(A, B) -> graduatedFrom(A, B)
# Chain: ['worksAt'] [3593]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.2740 : exports(A, B) -> imports(A, B)
# Chain: ['exports'] [631]
# Predicts: imports [2011] (same_cell)
#
# 0.2734 : created(A, B) -> directed(A, B)
# Chain: ['created'] [107]
# Predicts: directed [419] (same_cell)
#
# 0.2696 : hasMusicalRole(A, B) ^ influences(B, C) -> hasMusicalRole(A, C)
# Chain: ['hasMusicalRole', 'influences'] [1471, 2113]
# Predicts: hasMusicalRole [1471] (same_cell)
#
# 0.2662 : hasAcademicAdvisor(A, B) ^ worksAt(B, C) -> graduatedFrom(A, C)
# Chain: ['hasAcademicAdvisor', 'worksAt'] [941, 3593]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.2649 : imports(A, B) -> exports(A, B)
# Chain: ['imports'] [2011]
# Predicts: exports [631] (same_cell)
#
# 0.2376 : hasGender(A, B) ^ influences(B, C) -> hasGender(A, C)
# Chain: ['hasGender', 'influences'] [1361, 2113]
# Predicts: hasGender [1361] (same_cell)
#
# 0.2304 : livesIn(A, B) -> isCitizenOf(A, B)
# Chain: ['livesIn'] [3163]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.2222 : influences(A, B) ^ isKnownFor(B, C) -> isKnownFor(A, C)
# Chain: ['influences', 'isKnownFor'] [2113, 2647]
# Predicts: isKnownFor [2647] (same_cell)
#
# 0.2207 : hasChild(A, B) ^ hasWonPrize(B, C) -> hasWonPrize(A, C)
# Chain: ['hasChild', 'hasWonPrize'] [1151, 1907]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.2145 : diedIn(A, B) -> wasBornIn(A, B)
# Chain: ['diedIn'] [313]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.2128 : hasChild(A, B) ^ owns(B, C) -> owns(A, C)
# Chain: ['hasChild', 'owns'] [1151, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.2013 : isLeaderOf(A, B) -> isPoliticianOf(A, B)
# Chain: ['isLeaderOf'] [2749]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.2000 : influences(A, B) ^ isKnownFor(B, C) -> isKnownFor(A, C)
# Chain: ['influences', 'isKnownFor'] [2113, 2647]
# Predicts: isKnownFor [2647] (same_cell)
#
# 0.1948 : isCitizenOf(A, B) -> livesIn(A, B)
# Chain: ['isCitizenOf'] [2333]
# Predicts: livesIn [3163] (same_cell)
#
# 0.1920 : hasAcademicAdvisor(A, B) ^ hasGender(B, C) -> hasGender(A, C)
# Chain: ['hasAcademicAdvisor', 'hasGender'] [941, 1361]
# Predicts: hasGender [1361] (same_cell)
#
# 0.1897 : hasAcademicAdvisor(A, B) ^ hasWonPrize(B, C) -> hasWonPrize(A, C)
# Chain: ['hasAcademicAdvisor', 'hasWonPrize'] [941, 1907]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.1788 : actedIn(A, B) ^ dealsWith(B, C) -> dealsWith(A, C)
# Chain: ['actedIn', 'dealsWith'] [3, 211]
# Predicts: dealsWith [211] (same_cell)
#
# 0.1701 : directed(A, B) -> actedIn(A, B)
# Chain: ['directed'] [419]
# Predicts: actedIn [3] (same_cell)
#
# 0.1686 : happenedIn(A, B) -> isLocatedIn(A, B)
# Chain: ['happenedIn'] [839]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.1668 : graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) ^ worksAt(C, D) -> graduatedFrom(A, D)
# Chain: ['graduatedFrom', 'hasAcademicAdvisor', 'worksAt'] [733, 941, 3593]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.1627 : graduatedFrom(A, B) ^ hasChild(B, C) -> graduatedFrom(A, C)
# Chain: ['graduatedFrom', 'hasChild'] [733, 1151]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.1553 : graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# Chain: ['graduatedFrom', 'hasAcademicAdvisor', 'worksAt'] [733, 941, 3593]
# Predicts: worksAt [3593] (same_cell)
#
# 0.1548 : isLeaderOf(A, B) -> isAffiliatedTo(A, B)
# Chain: ['isLeaderOf'] [2749]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.1541 : hasAcademicAdvisor(A, B) ^ worksAt(B, C) -> worksAt(A, C)
# Chain: ['hasAcademicAdvisor', 'worksAt'] [941, 3593]
# Predicts: worksAt [3593] (same_cell)
#
# 0.1506 : graduatedFrom(A, B) -> worksAt(A, B)
# Chain: ['graduatedFrom'] [733]
# Predicts: worksAt [3593] (same_cell)
#
# 0.1468 : created(A, B) -> wroteMusicFor(A, B)
# Chain: ['created'] [107]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.1422 : dealsWith(A, B) ^ hasOfficialLanguage(B, C) -> hasOfficialLanguage(A, C)
# Chain: ['dealsWith', 'hasOfficialLanguage'] [211, 1693]
# Predicts: hasOfficialLanguage [1693] (same_cell)
#
# 0.1421 : isPoliticianOf(A, B) -> isCitizenOf(A, B)
# Chain: ['isPoliticianOf'] [3061]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.1382 : dealsWith(A, B) ^ exports(B, C) -> exports(A, C)
# Chain: ['dealsWith', 'exports'] [211, 631]
# Predicts: exports [631] (same_cell)
#
# 0.1375 : dealsWith(A, B) ^ imports(B, C) -> imports(A, C)
# Chain: ['dealsWith', 'imports'] [211, 2011]
# Predicts: imports [2011] (same_cell)
#
# 0.1333 : created(A, B) ^ directed(B, C) ^ hasChild(C, D) ^ wroteMusicFor(D, E) -> wroteMusicFor(A, E)
# Chain: ['created', 'directed', 'hasChild', 'wroteMusicFor'] [107, 419, 1151, 3697]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.1327 : wroteMusicFor(A, B) -> created(A, B)
# Chain: ['wroteMusicFor'] [3697]
# Predicts: created [107] (same_cell)
#
# 0.1327 : happenedIn(A, B) ^ isLocatedIn(B, C) -> happenedIn(A, C)
# Chain: ['happenedIn', 'isLocatedIn'] [839, 2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.1327 : graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) -> graduatedFrom(A, C)
# Chain: ['graduatedFrom', 'hasAcademicAdvisor'] [733, 941]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.1320 : hasChild(A, B) -> hasChild(A, B)
# Chain: ['hasChild'] [1151]
# Predicts: hasChild [1151] (same_cell)
#
# 0.1314 : actedIn(A, B) ^ isConnectedTo(B, C) -> isConnectedTo(A, C)
# Chain: ['actedIn', 'isConnectedTo'] [3, 2437]
# Predicts: isConnectedTo [2437] (same_cell)
#
# 0.1304 : actedIn(A, B) ^ dealsWith(B, C) ^ hasCurrency(C, D) -> hasCurrency(A, D)
# Chain: ['actedIn', 'dealsWith', 'hasCurrency'] [3, 211, 1259]
# Predicts: hasCurrency [1259] (same_cell)
#
# 0.1256 : dealsWith(A, B) -> dealsWith(A, B)
# Chain: ['dealsWith'] [211]
# Predicts: dealsWith [211] (same_cell)
#
# 0.1212 : dealsWith(A, B) ^ hasCurrency(B, C) ^ isLocatedIn(C, D) -> hasCurrency(A, D)
# Chain: ['dealsWith', 'hasCurrency', 'isLocatedIn'] [211, 1259, 2851]
# Predicts: hasCurrency [1259] (same_cell)
#
# 0.1209 : happenedIn(A, B) ^ isLocatedIn(B, C) -> happenedIn(A, C)
# Chain: ['happenedIn', 'isLocatedIn'] [839, 2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.1200 : hasWebsite(A, B) ^ isLocatedIn(B, C) -> hasWebsite(A, C)
# Chain: ['hasWebsite', 'isLocatedIn'] [1801, 2851]
# Predicts: hasWebsite [1801] (same_cell)
#
# 0.1189 : actedIn(A, B) ^ dealsWith(B, C) ^ hasOfficialLanguage(C, D) -> hasOfficialLanguage(A, D)
# Chain: ['actedIn', 'dealsWith', 'hasOfficialLanguage'] [3, 211, 1693]
# Predicts: hasOfficialLanguage [1693] (same_cell)
#
# 0.1182 : actedIn(A, B) ^ influences(B, C) -> influences(A, C)
# Chain: ['actedIn', 'influences'] [3, 2113]
# Predicts: influences [2113] (same_cell)
#
# 0.1173 : created(A, B) -> actedIn(A, B)
# Chain: ['created'] [107]
# Predicts: actedIn [3] (same_cell)
#
# 0.1139 : isLocatedIn(A, B) ^ livesIn(B, C) -> livesIn(A, C)
# Chain: ['isLocatedIn', 'livesIn'] [2851, 3163]
# Predicts: livesIn [3163] (same_cell)
#
# 0.1132 : hasChild(A, B) ^ wroteMusicFor(B, C) -> wroteMusicFor(A, C)
# Chain: ['hasChild', 'wroteMusicFor'] [1151, 3697]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.1122 : isPoliticianOf(A, B) -> isLeaderOf(A, B)
# Chain: ['isPoliticianOf'] [3061]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.1111 : dealsWith(A, B) ^ isKnownFor(B, C) -> isKnownFor(A, C)
# Chain: ['dealsWith', 'isKnownFor'] [211, 2647]
# Predicts: isKnownFor [2647] (same_cell)
#
# 0.1075 : owns(A, B) -> owns(A, B)
# Chain: ['owns'] [3271]
# Predicts: owns [3271] (same_cell)
#
# 0.1053 : isMarriedTo(A, B) ^ wroteMusicFor(B, C) -> wroteMusicFor(A, C)
# Chain: ['isMarriedTo', 'wroteMusicFor'] [2953, 3697]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.1018 : isCitizenOf(A, B) -> isPoliticianOf(A, B)
# Chain: ['isCitizenOf'] [2333]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.0952 : isKnownFor(A, B) -> isInterestedIn(A, B)
# Chain: ['isKnownFor'] [2647]
# Predicts: isInterestedIn [2539] (same_cell)
#
# 0.0950 : isConnectedTo(A, B) -> isConnectedTo(A, B)
# Chain: ['isConnectedTo'] [2437]
# Predicts: isConnectedTo [2437] (same_cell)
#
# 0.0936 : hasGender(A, B) ^ isAffiliatedTo(B, C) -> hasGender(A, C)
# Chain: ['hasGender', 'isAffiliatedTo'] [1361, 2221]
# Predicts: hasGender [1361] (same_cell)
#
# 0.0909 : hasNeighbor(A, B) -> dealsWith(A, B)
# Chain: ['hasNeighbor'] [1579]
# Predicts: dealsWith [211] (same_cell)
#
# 0.0903 : hasWonPrize(A, B) ^ influences(B, C) -> hasWonPrize(A, C)
# Chain: ['hasWonPrize', 'influences'] [1907, 2113]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0833 : created(A, B) -> directed(A, B)
# Chain: ['created'] [107]
# Predicts: directed [419] (same_cell)
#
# 0.0799 : graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) -> worksAt(A, C)
# Chain: ['graduatedFrom', 'hasAcademicAdvisor'] [733, 941]
# Predicts: worksAt [3593] (same_cell)
#
# 0.0797 : dealsWith(A, B) ^ happenedIn(B, C) -> happenedIn(A, C)
# Chain: ['dealsWith', 'happenedIn'] [211, 839]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0795 : actedIn(A, B) ^ influences(B, C) ^ isInterestedIn(C, D) -> isInterestedIn(A, D)
# Chain: ['actedIn', 'influences', 'isInterestedIn'] [3, 2113, 2539]
# Predicts: isInterestedIn [2539] (same_cell)
#
# 0.0787 : influences(A, B) -> influences(A, B)
# Chain: ['influences'] [2113]
# Predicts: influences [2113] (same_cell)
#
# 0.0784 : diedIn(A, B) ^ hasWonPrize(B, C) -> hasWonPrize(A, C)
# Chain: ['diedIn', 'hasWonPrize'] [313, 1907]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0760 : isLeaderOf(A, B) -> livesIn(A, B)
# Chain: ['isLeaderOf'] [2749]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0757 : isAffiliatedTo(A, B) ^ isLocatedIn(B, C) -> wasBornIn(A, C)
# Chain: ['isAffiliatedTo', 'isLocatedIn'] [2221, 2851]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0741 : actedIn(A, B) ^ dealsWith(B, C) ^ exports(C, D) -> exports(A, D)
# Chain: ['actedIn', 'dealsWith', 'exports'] [3, 211, 631]
# Predicts: exports [631] (same_cell)
#
# 0.0737 : actedIn(A, B) ^ dealsWith(B, C) ^ participatedIn(C, D) -> participatedIn(A, D)
# Chain: ['actedIn', 'dealsWith', 'participatedIn'] [3, 211, 3373]
# Predicts: participatedIn [3373] (same_cell)
#
# 0.0714 : created(A, B) -> actedIn(A, B)
# Chain: ['created'] [107]
# Predicts: actedIn [3] (same_cell)
#
# 0.0709 : influences(A, B) ^ isInterestedIn(B, C) -> isInterestedIn(A, C)
# Chain: ['influences', 'isInterestedIn'] [2113, 2539]
# Predicts: isInterestedIn [2539] (same_cell)
#
# 0.0704 : hasChild(A, B) ^ isPoliticianOf(B, C) -> isPoliticianOf(A, C)
# Chain: ['hasChild', 'isPoliticianOf'] [1151, 3061]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.0680 : hasCapital(A, B) ^ livesIn(B, C) -> livesIn(A, C)
# Chain: ['hasCapital', 'livesIn'] [1049, 3163]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0671 : actedIn(A, B) ^ hasGender(B, C) ^ influences(C, D) -> hasGender(A, D)
# Chain: ['actedIn', 'hasGender', 'influences'] [3, 1361, 2113]
# Predicts: hasGender [1361] (same_cell)
#
# 0.0659 : directed(A, B) ^ hasChild(B, C) -> wroteMusicFor(A, C)
# Chain: ['directed', 'hasChild'] [419, 1151]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.0634 : livesIn(A, B) -> wasBornIn(A, B)
# Chain: ['livesIn'] [3163]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0629 : dealsWith(A, B) ^ hasOfficialLanguage(B, C) ^ isLocatedIn(C, D) -> hasOfficialLanguage(A, D)
# Chain: ['dealsWith', 'hasOfficialLanguage', 'isLocatedIn'] [211, 1693, 2851]
# Predicts: hasOfficialLanguage [1693] (same_cell)
#
# 0.0627 : isAffiliatedTo(A, B) -> isAffiliatedTo(A, B)
# Chain: ['isAffiliatedTo'] [2221]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0625 : hasCurrency(A, B) ^ hasNeighbor(B, C) -> hasCurrency(A, C)
# Chain: ['hasCurrency', 'hasNeighbor'] [1259, 1579]
# Predicts: hasCurrency [1259] (same_cell)
#
# 0.0625 : actedIn(A, B) ^ created(B, C) ^ directed(C, D) -> created(A, D)
# Chain: ['actedIn', 'created', 'directed'] [3, 107, 419]
# Predicts: created [107] (same_cell)
#
# 0.0621 : actedIn(A, B) ^ isLocatedIn(B, C) -> isLocatedIn(A, C)
# Chain: ['actedIn', 'isLocatedIn'] [3, 2851]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0618 : actedIn(A, B) ^ hasChild(B, C) ^ hasGender(C, D) -> hasGender(A, D)
# Chain: ['actedIn', 'hasChild', 'hasGender'] [3, 1151, 1361]
# Predicts: hasGender [1361] (same_cell)
#
# 0.0617 : created(A, B) ^ owns(B, C) -> created(A, C)
# Chain: ['created', 'owns'] [107, 3271]
# Predicts: created [107] (same_cell)
#
# 0.0606 : actedIn(A, B) ^ dealsWith(B, C) ^ imports(C, D) -> imports(A, D)
# Chain: ['actedIn', 'dealsWith', 'imports'] [3, 211, 2011]
# Predicts: imports [2011] (same_cell)
#
# 0.0606 : actedIn(A, B) ^ created(B, C) ^ directed(C, D) -> actedIn(A, D)
# Chain: ['actedIn', 'created', 'directed'] [3, 107, 419]
# Predicts: actedIn [3] (same_cell)
#
# 0.0599 : actedIn(A, B) ^ dealsWith(B, C) ^ imports(C, D) -> imports(A, D)
# Chain: ['actedIn', 'dealsWith', 'imports'] [3, 211, 2011]
# Predicts: imports [2011] (same_cell)
#
# 0.0597 : hasChild(A, B) ^ wroteMusicFor(B, C) -> directed(A, C)
# Chain: ['hasChild', 'wroteMusicFor'] [1151, 3697]
# Predicts: directed [419] (same_cell)
#
# 0.0588 : created(A, B) ^ directed(B, C) ^ hasChild(C, D) -> wroteMusicFor(A, D)
# Chain: ['created', 'directed', 'hasChild'] [107, 419, 1151]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.0587 : dealsWith(A, B) ^ hasCurrency(B, C) -> hasCurrency(A, C)
# Chain: ['dealsWith', 'hasCurrency'] [211, 1259]
# Predicts: hasCurrency [1259] (same_cell)
#
# 0.0567 : actedIn(A, B) ^ hasChild(B, C) ^ isAffiliatedTo(C, D) -> isAffiliatedTo(A, D)
# Chain: ['actedIn', 'hasChild', 'isAffiliatedTo'] [3, 1151, 2221]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0566 : isPoliticianOf(A, B) -> livesIn(A, B)
# Chain: ['isPoliticianOf'] [3061]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0560 : isLocatedIn(A, B) ^ worksAt(B, C) -> diedIn(A, C)
# Chain: ['isLocatedIn', 'worksAt'] [2851, 3593]
# Predicts: diedIn [313] (same_cell)
#
# 0.0526 : hasChild(A, B) ^ hasMusicalRole(B, C) -> hasMusicalRole(A, C)
# Chain: ['hasChild', 'hasMusicalRole'] [1151, 1471]
# Predicts: hasMusicalRole [1471] (same_cell)
#
# 0.0525 : dealsWith(A, B) ^ exports(B, C) ^ imports(C, D) -> exports(A, D)
# Chain: ['dealsWith', 'exports', 'imports'] [211, 631, 2011]
# Predicts: exports [631] (same_cell)
#
# 0.0522 : hasChild(A, B) ^ wasBornIn(B, C) -> diedIn(A, C)
# Chain: ['hasChild', 'wasBornIn'] [1151, 3491]
# Predicts: diedIn [313] (same_cell)
#
# 0.0515 : isLeaderOf(A, B) ^ isLocatedIn(B, C) -> isLeaderOf(A, C)
# Chain: ['isLeaderOf', 'isLocatedIn'] [2749, 2851]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0499 : hasChild(A, B) ^ isMarriedTo(B, C) -> hasChild(A, C)
# Chain: ['hasChild', 'isMarriedTo'] [1151, 2953]
# Predicts: hasChild [1151] (same_cell)
#
# 0.0494 : actedIn(A, B) ^ directed(B, C) ^ hasChild(C, D) -> actedIn(A, D)
# Chain: ['actedIn', 'directed', 'hasChild'] [3, 419, 1151]
# Predicts: actedIn [3] (same_cell)
#
# 0.0492 : livesIn(A, B) -> isPoliticianOf(A, B)
# Chain: ['livesIn'] [3163]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.0490 : wasBornIn(A, B) -> diedIn(A, B)
# Chain: ['wasBornIn'] [3491]
# Predicts: diedIn [313] (same_cell)
#
# 0.0483 : livesIn(A, B) -> diedIn(A, B)
# Chain: ['livesIn'] [3163]
# Predicts: diedIn [313] (same_cell)
#
# 0.0477 : hasAcademicAdvisor(A, B) -> hasAcademicAdvisor(A, B)
# Chain: ['hasAcademicAdvisor'] [941]
# Predicts: hasAcademicAdvisor [941] (same_cell)
#
# 0.0473 : hasCapital(A, B) ^ isLocatedIn(B, C) -> isLocatedIn(A, C)
# Chain: ['hasCapital', 'isLocatedIn'] [1049, 2851]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0460 : actedIn(A, B) ^ hasMusicalRole(B, C) ^ influences(C, D) -> hasMusicalRole(A, D)
# Chain: ['actedIn', 'hasMusicalRole', 'influences'] [3, 1471, 2113]
# Predicts: hasMusicalRole [1471] (same_cell)
#
# 0.0458 : actedIn(A, B) ^ happenedIn(B, C) ^ isLocatedIn(C, D) -> happenedIn(A, D)
# Chain: ['actedIn', 'happenedIn', 'isLocatedIn'] [3, 839, 2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0435 : actedIn(A, B) ^ influences(B, C) ^ isInterestedIn(C, D) -> isInterestedIn(A, D)
# Chain: ['actedIn', 'influences', 'isInterestedIn'] [3, 2113, 2539]
# Predicts: isInterestedIn [2539] (same_cell)
#
# 0.0435 : isMarriedTo(A, B) -> hasChild(A, B)
# Chain: ['isMarriedTo'] [2953]
# Predicts: hasChild [1151] (same_cell)
#
# 0.0429 : actedIn(A, B) ^ hasWonPrize(B, C) ^ influences(C, D) -> hasWonPrize(A, D)
# Chain: ['actedIn', 'hasWonPrize', 'influences'] [3, 1907, 2113]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0419 : graduatedFrom(A, B) ^ isLocatedIn(B, C) -> wasBornIn(A, C)
# Chain: ['graduatedFrom', 'isLocatedIn'] [733, 2851]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0413 : diedIn(A, B) ^ hasChild(B, C) -> diedIn(A, C)
# Chain: ['diedIn', 'hasChild'] [313, 1151]
# Predicts: diedIn [313] (same_cell)
#
# 0.0411 : dealsWith(A, B) ^ exports(B, C) ^ imports(C, D) -> imports(A, D)
# Chain: ['dealsWith', 'exports', 'imports'] [211, 631, 2011]
# Predicts: imports [2011] (same_cell)
#
# 0.0406 : influences(A, B) ^ worksAt(B, C) -> worksAt(A, C)
# Chain: ['influences', 'worksAt'] [2113, 3593]
# Predicts: worksAt [3593] (same_cell)
#
# 0.0406 : dealsWith(A, B) ^ imports(B, C) -> exports(A, C)
# Chain: ['dealsWith', 'imports'] [211, 2011]
# Predicts: exports [631] (same_cell)
#
# 0.0405 : livesIn(A, B) -> isLeaderOf(A, B)
# Chain: ['livesIn'] [3163]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0395 : hasChild(A, B) ^ isAffiliatedTo(B, C) ^ isLeaderOf(C, D) -> isAffiliatedTo(A, D)
# Chain: ['hasChild', 'isAffiliatedTo', 'isLeaderOf'] [1151, 2221, 2749]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0351 : hasChild(A, B) ^ isAffiliatedTo(B, C) ^ isLeaderOf(C, D) -> isLeaderOf(A, D)
# Chain: ['hasChild', 'isAffiliatedTo', 'isLeaderOf'] [1151, 2221, 2749]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0347 : hasCapital(A, B) ^ isLocatedIn(B, C) -> isLocatedIn(A, C)
# Chain: ['hasCapital', 'isLocatedIn'] [1049, 2851]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0339 : isAffiliatedTo(A, B) ^ owns(B, C) -> isAffiliatedTo(A, C)
# Chain: ['isAffiliatedTo', 'owns'] [2221, 3271]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0337 : graduatedFrom(A, B) ^ influences(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# Chain: ['graduatedFrom', 'influences', 'worksAt'] [733, 2113, 3593]
# Predicts: worksAt [3593] (same_cell)
#
# 0.0333 : dealsWith(A, B) ^ participatedIn(B, C) -> participatedIn(A, C)
# Chain: ['dealsWith', 'participatedIn'] [211, 3373]
# Predicts: participatedIn [3373] (same_cell)
#
# 0.0328 : actedIn(A, B) ^ hasChild(B, C) -> hasChild(A, C)
# Chain: ['actedIn', 'hasChild'] [3, 1151]
# Predicts: hasChild [1151] (same_cell)
#
# 0.0328 : actedIn(A, B) -> directed(A, B)
# Chain: ['actedIn'] [3]
# Predicts: directed [419] (same_cell)
#
# 0.0327 : hasCapital(A, B) ^ isLocatedIn(B, C) ^ livesIn(C, D) -> livesIn(A, D)
# Chain: ['hasCapital', 'isLocatedIn', 'livesIn'] [1049, 2851, 3163]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0308 : actedIn(A, B) ^ hasChild(B, C) -> actedIn(A, C)
# Chain: ['actedIn', 'hasChild'] [3, 1151]
# Predicts: actedIn [3] (same_cell)
#
# 0.0306 : actedIn(A, B) ^ dealsWith(B, C) ^ exports(C, D) -> imports(A, D)
# Chain: ['actedIn', 'dealsWith', 'exports'] [3, 211, 631]
# Predicts: imports [2011] (same_cell)
#
# 0.0303 : created(A, B) ^ hasChild(B, C) ^ influences(C, D) -> created(A, D)
# Chain: ['created', 'hasChild', 'influences'] [107, 1151, 2113]
# Predicts: created [107] (same_cell)
#
# 0.0303 : isLeaderOf(A, B) ^ isLocatedIn(B, C) ^ livesIn(C, D) -> isLeaderOf(A, D)
# Chain: ['isLeaderOf', 'isLocatedIn', 'livesIn'] [2749, 2851, 3163]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0294 : dealsWith(A, B) ^ exports(B, C) -> imports(A, C)
# Chain: ['dealsWith', 'exports'] [211, 631]
# Predicts: imports [2011] (same_cell)
#
# 0.0293 : diedIn(A, B) ^ hasChild(B, C) ^ wasBornIn(C, D) -> diedIn(A, D)
# Chain: ['diedIn', 'hasChild', 'wasBornIn'] [313, 1151, 3491]
# Predicts: diedIn [313] (same_cell)
#
# 0.0292 : actedIn(A, B) ^ dealsWith(B, C) -> dealsWith(A, C)
# Chain: ['actedIn', 'dealsWith'] [3, 211]
# Predicts: dealsWith [211] (same_cell)
#
# 0.0290 : actedIn(A, B) ^ created(B, C) ^ hasChild(C, D) -> actedIn(A, D)
# Chain: ['actedIn', 'created', 'hasChild'] [3, 107, 1151]
# Predicts: actedIn [3] (same_cell)
#
# 0.0288 : actedIn(A, B) ^ isAffiliatedTo(B, C) ^ isLocatedIn(C, D) -> wasBornIn(A, D)
# Chain: ['actedIn', 'isAffiliatedTo', 'isLocatedIn'] [3, 2221, 2851]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0288 : actedIn(A, B) ^ created(B, C) ^ influences(C, D) -> created(A, D)
# Chain: ['actedIn', 'created', 'influences'] [3, 107, 2113]
# Predicts: created [107] (same_cell)
#
# 0.0286 : created(A, B) ^ hasAcademicAdvisor(B, C) ^ worksAt(C, D) -> created(A, D)
# Chain: ['created', 'hasAcademicAdvisor', 'worksAt'] [107, 941, 3593]
# Predicts: created [107] (same_cell)
#
# 0.0284 : dealsWith(A, B) ^ happenedIn(B, C) ^ isLocatedIn(C, D) -> happenedIn(A, D)
# Chain: ['dealsWith', 'happenedIn', 'isLocatedIn'] [211, 839, 2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0284 : actedIn(A, B) ^ created(B, C) ^ influences(C, D) -> actedIn(A, D)
# Chain: ['actedIn', 'created', 'influences'] [3, 107, 2113]
# Predicts: actedIn [3] (same_cell)
#
# 0.0280 : hasCapital(A, B) ^ isPoliticianOf(B, C) -> diedIn(A, C)
# Chain: ['hasCapital', 'isPoliticianOf'] [1049, 3061]
# Predicts: diedIn [313] (same_cell)
#
# 0.0273 : actedIn(A, B) -> created(A, B)
# Chain: ['actedIn'] [3]
# Predicts: created [107] (same_cell)
#
# 0.0270 : actedIn(A, B) ^ created(B, C) ^ directed(C, D) ^ hasChild(D, E) -> actedIn(A, E)
# Chain: ['actedIn', 'created', 'directed', 'hasChild'] [3, 107, 419, 1151]
# Predicts: actedIn [3] (same_cell)
#
# 0.0267 : diedIn(A, B) ^ influences(B, C) -> diedIn(A, C)
# Chain: ['diedIn', 'influences'] [313, 2113]
# Predicts: diedIn [313] (same_cell)
#
# 0.0260 : isLocatedIn(A, B) ^ worksAt(B, C) -> livesIn(A, C)
# Chain: ['isLocatedIn', 'worksAt'] [2851, 3593]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0260 : isLeaderOf(A, B) ^ isLocatedIn(B, C) ^ wasBornIn(C, D) -> isLeaderOf(A, D)
# Chain: ['isLeaderOf', 'isLocatedIn', 'wasBornIn'] [2749, 2851, 3491]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0256 : isLeaderOf(A, B) -> wasBornIn(A, B)
# Chain: ['isLeaderOf'] [2749]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0256 : hasChild(A, B) ^ wasBornIn(B, C) -> wasBornIn(A, C)
# Chain: ['hasChild', 'wasBornIn'] [1151, 3491]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0248 : hasCapital(A, B) ^ isCitizenOf(B, C) -> diedIn(A, C)
# Chain: ['hasCapital', 'isCitizenOf'] [1049, 2333]
# Predicts: diedIn [313] (same_cell)
#
# 0.0244 : created(A, B) -> created(A, B)
# Chain: ['created'] [107]
# Predicts: created [107] (same_cell)
#
# 0.0244 : happenedIn(A, B) ^ hasCapital(B, C) ^ isLocatedIn(C, D) -> happenedIn(A, D)
# Chain: ['happenedIn', 'hasCapital', 'isLocatedIn'] [839, 1049, 2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0240 : isConnectedTo(A, B) ^ owns(B, C) -> owns(A, C)
# Chain: ['isConnectedTo', 'owns'] [2437, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.0233 : graduatedFrom(A, B) ^ isLocatedIn(B, C) ^ worksAt(C, D) -> diedIn(A, D)
# Chain: ['graduatedFrom', 'isLocatedIn', 'worksAt'] [733, 2851, 3593]
# Predicts: diedIn [313] (same_cell)
#
# 0.0233 : graduatedFrom(A, B) ^ influences(B, C) -> graduatedFrom(A, C)
# Chain: ['graduatedFrom', 'influences'] [733, 2113]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.0231 : edited(A, B) -> directed(A, B)
# Chain: ['edited'] [521]
# Predicts: directed [419] (same_cell)
#
# 0.0229 : actedIn(A, B) ^ isConnectedTo(B, C) -> isConnectedTo(A, C)
# Chain: ['actedIn', 'isConnectedTo'] [3, 2437]
# Predicts: isConnectedTo [2437] (same_cell)
#
# 0.0225 : created(A, B) ^ hasMusicalRole(B, C) -> hasMusicalRole(A, C)
# Chain: ['created', 'hasMusicalRole'] [107, 1471]
# Predicts: hasMusicalRole [1471] (same_cell)
#
# 0.0224 : actedIn(A, B) ^ hasChild(B, C) ^ hasWonPrize(C, D) -> hasWonPrize(A, D)
# Chain: ['actedIn', 'hasChild', 'hasWonPrize'] [3, 1151, 1907]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0223 : hasCapital(A, B) ^ isCitizenOf(B, C) -> wasBornIn(A, C)
# Chain: ['hasCapital', 'isCitizenOf'] [1049, 2333]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0222 : hasCapital(A, B) ^ owns(B, C) -> owns(A, C)
# Chain: ['hasCapital', 'owns'] [1049, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.0221 : isLocatedIn(A, B) -> hasCapital(A, B)
# Chain: ['isLocatedIn'] [2851]
# Predicts: hasCapital [1049] (same_cell)
#
# 0.0220 : actedIn(A, B) ^ dealsWith(B, C) ^ imports(C, D) -> exports(A, D)
# Chain: ['actedIn', 'dealsWith', 'imports'] [3, 211, 2011]
# Predicts: exports [631] (same_cell)
#
# 0.0217 : isInterestedIn(A, B) -> isInterestedIn(A, B)
# Chain: ['isInterestedIn'] [2539]
# Predicts: isInterestedIn [2539] (same_cell)
#
# 0.0216 : actedIn(A, B) ^ dealsWith(B, C) ^ participatedIn(C, D) -> participatedIn(A, D)
# Chain: ['actedIn', 'dealsWith', 'participatedIn'] [3, 211, 3373]
# Predicts: participatedIn [3373] (same_cell)
#
# 0.0204 : actedIn(A, B) ^ hasChild(B, C) ^ owns(C, D) -> owns(A, D)
# Chain: ['actedIn', 'hasChild', 'owns'] [3, 1151, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.0204 : directed(A, B) -> edited(A, B)
# Chain: ['directed'] [419]
# Predicts: edited [521] (same_cell)
#
# 0.0203 : diedIn(A, B) -> livesIn(A, B)
# Chain: ['diedIn'] [313]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0201 : hasCapital(A, B) ^ isLocatedIn(B, C) -> hasCapital(A, C)
# Chain: ['hasCapital', 'isLocatedIn'] [1049, 2851]
# Predicts: hasCapital [1049] (same_cell)
#
# 0.0198 : hasChild(A, B) ^ wroteMusicFor(B, C) -> created(A, C)
# Chain: ['hasChild', 'wroteMusicFor'] [1151, 3697]
# Predicts: created [107] (same_cell)
#
# 0.0197 : isLeaderOf(A, B) ^ isLocatedIn(B, C) ^ livesIn(C, D) ^ wasBornIn(D, E) -> isLeaderOf(A, E)
# Chain: ['isLeaderOf', 'isLocatedIn', 'livesIn', 'wasBornIn'] [2749, 2851, 3163, 3491]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0193 : owns(A, B) ^ wasBornIn(B, C) -> isAffiliatedTo(A, C)
# Chain: ['owns', 'wasBornIn'] [3271, 3491]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0191 : graduatedFrom(A, B) ^ influences(B, C) -> worksAt(A, C)
# Chain: ['graduatedFrom', 'influences'] [733, 2113]
# Predicts: worksAt [3593] (same_cell)
#
# 0.0190 : directed(A, B) ^ hasChild(B, C) -> directed(A, C)
# Chain: ['directed', 'hasChild'] [419, 1151]
# Predicts: directed [419] (same_cell)
#
# 0.0188 : actedIn(A, B) ^ dealsWith(B, C) ^ happenedIn(C, D) -> happenedIn(A, D)
# Chain: ['actedIn', 'dealsWith', 'happenedIn'] [3, 211, 839]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0177 : influences(A, B) ^ wroteMusicFor(B, C) -> directed(A, C)
# Chain: ['influences', 'wroteMusicFor'] [2113, 3697]
# Predicts: directed [419] (same_cell)
#
# 0.0176 : hasCapital(A, B) -> hasCapital(A, B)
# Chain: ['hasCapital'] [1049]
# Predicts: hasCapital [1049] (same_cell)
#
# 0.0176 : graduatedFrom(A, B) ^ isLocatedIn(B, C) -> diedIn(A, C)
# Chain: ['graduatedFrom', 'isLocatedIn'] [733, 2851]
# Predicts: diedIn [313] (same_cell)
#
# 0.0176 : influences(A, B) ^ worksAt(B, C) -> graduatedFrom(A, C)
# Chain: ['influences', 'worksAt'] [2113, 3593]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.0170 : isLocatedIn(A, B) ^ livesIn(B, C) ^ wasBornIn(C, D) -> livesIn(A, D)
# Chain: ['isLocatedIn', 'livesIn', 'wasBornIn'] [2851, 3163, 3491]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0168 : graduatedFrom(A, B) ^ influences(B, C) ^ worksAt(C, D) -> graduatedFrom(A, D)
# Chain: ['graduatedFrom', 'influences', 'worksAt'] [733, 2113, 3593]
# Predicts: graduatedFrom [733] (same_cell)
#
# 0.0165 : actedIn(A, B) ^ influences(B, C) -> actedIn(A, C)
# Chain: ['actedIn', 'influences'] [3, 2113]
# Predicts: actedIn [3] (same_cell)
#
# 0.0162 : happenedIn(A, B) ^ hasCapital(B, C) -> happenedIn(A, C)
# Chain: ['happenedIn', 'hasCapital'] [839, 1049]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0161 : created(A, B) ^ hasChild(B, C) -> directed(A, C)
# Chain: ['created', 'hasChild'] [107, 1151]
# Predicts: directed [419] (same_cell)
#
# 0.0156 : influences(A, B) ^ isKnownFor(B, C) -> isKnownFor(A, C)
# Chain: ['influences', 'isKnownFor'] [2113, 2647]
# Predicts: isKnownFor [2647] (same_cell)
#
# 0.0153 : hasAcademicAdvisor(A, B) ^ isCitizenOf(B, C) -> isCitizenOf(A, C)
# Chain: ['hasAcademicAdvisor', 'isCitizenOf'] [941, 2333]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.0153 : actedIn(A, B) ^ hasChild(B, C) ^ influences(C, D) -> hasChild(A, D)
# Chain: ['actedIn', 'hasChild', 'influences'] [3, 1151, 2113]
# Predicts: hasChild [1151] (same_cell)
#
# 0.0145 : dealsWith(A, B) ^ isLocatedIn(B, C) -> isLocatedIn(A, C)
# Chain: ['dealsWith', 'isLocatedIn'] [211, 2851]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0144 : directed(A, B) ^ hasChild(B, C) -> created(A, C)
# Chain: ['directed', 'hasChild'] [419, 1151]
# Predicts: created [107] (same_cell)
#
# 0.0144 : directed(A, B) -> wroteMusicFor(A, B)
# Chain: ['directed'] [419]
# Predicts: wroteMusicFor [3697] (same_cell)
#
# 0.0142 : directed(A, B) ^ hasChild(B, C) -> actedIn(A, C)
# Chain: ['directed', 'hasChild'] [419, 1151]
# Predicts: actedIn [3] (same_cell)
#
# 0.0140 : actedIn(A, B) ^ hasChild(B, C) -> directed(A, C)
# Chain: ['actedIn', 'hasChild'] [3, 1151]
# Predicts: directed [419] (same_cell)
#
# 0.0138 : hasChild(A, B) ^ isLeaderOf(B, C) ^ isPoliticianOf(C, D) -> isLeaderOf(A, D)
# Chain: ['hasChild', 'isLeaderOf', 'isPoliticianOf'] [1151, 2749, 3061]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0138 : owns(A, B) -> isLocatedIn(A, B)
# Chain: ['owns'] [3271]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0136 : isLocatedIn(A, B) ^ owns(B, C) -> owns(A, C)
# Chain: ['isLocatedIn', 'owns'] [2851, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.0134 : influences(A, B) ^ isCitizenOf(B, C) -> isCitizenOf(A, C)
# Chain: ['influences', 'isCitizenOf'] [2113, 2333]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.0129 : graduatedFrom(A, B) ^ isLocatedIn(B, C) ^ worksAt(C, D) -> livesIn(A, D)
# Chain: ['graduatedFrom', 'isLocatedIn', 'worksAt'] [733, 2851, 3593]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0128 : graduatedFrom(A, B) ^ isLocatedIn(B, C) -> livesIn(A, C)
# Chain: ['graduatedFrom', 'isLocatedIn'] [733, 2851]
# Predicts: livesIn [3163] (same_cell)
#
# 0.0128 : graduatedFrom(A, B) ^ hasChild(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# Chain: ['graduatedFrom', 'hasChild', 'worksAt'] [733, 1151, 3593]
# Predicts: worksAt [3593] (same_cell)
#
# 0.0128 : graduatedFrom(A, B) ^ isLocatedIn(B, C) -> isCitizenOf(A, C)
# Chain: ['graduatedFrom', 'isLocatedIn'] [733, 2851]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.0127 : created(A, B) ^ hasChild(B, C) -> created(A, C)
# Chain: ['created', 'hasChild'] [107, 1151]
# Predicts: created [107] (same_cell)
#
# 0.0126 : diedIn(A, B) ^ hasWonPrize(B, C) ^ wasBornIn(C, D) -> hasWonPrize(A, D)
# Chain: ['diedIn', 'hasWonPrize', 'wasBornIn'] [313, 1907, 3491]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0126 : actedIn(A, B) ^ isLeaderOf(B, C) ^ isLocatedIn(C, D) -> isLeaderOf(A, D)
# Chain: ['actedIn', 'isLeaderOf', 'isLocatedIn'] [3, 2749, 2851]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0126 : edited(A, B) -> created(A, B)
# Chain: ['edited'] [521]
# Predicts: created [107] (same_cell)
#
# 0.0126 : isLocatedIn(A, B) -> happenedIn(A, B)
# Chain: ['isLocatedIn'] [2851]
# Predicts: happenedIn [839] (same_cell)
#
# 0.0123 : directed(A, B) ^ influences(B, C) -> created(A, C)
# Chain: ['directed', 'influences'] [419, 2113]
# Predicts: created [107] (same_cell)
#
# 0.0122 : hasWonPrize(A, B) ^ isAffiliatedTo(B, C) -> hasWonPrize(A, C)
# Chain: ['hasWonPrize', 'isAffiliatedTo'] [1907, 2221]
# Predicts: hasWonPrize [1907] (same_cell)
#
# 0.0121 : actedIn(A, B) ^ hasChild(B, C) ^ isAffiliatedTo(C, D) -> isLeaderOf(A, D)
# Chain: ['actedIn', 'hasChild', 'isAffiliatedTo'] [3, 1151, 2221]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0116 : graduatedFrom(A, B) ^ owns(B, C) -> created(A, C)
# Chain: ['graduatedFrom', 'owns'] [733, 3271]
# Predicts: created [107] (same_cell)
#
# 0.0115 : isAffiliatedTo(A, B) ^ owns(B, C) -> wasBornIn(A, C)
# Chain: ['isAffiliatedTo', 'owns'] [2221, 3271]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0115 : hasChild(A, B) ^ isAffiliatedTo(B, C) -> isLeaderOf(A, C)
# Chain: ['hasChild', 'isAffiliatedTo'] [1151, 2221]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0115 : hasCapital(A, B) ^ isPoliticianOf(B, C) -> wasBornIn(A, C)
# Chain: ['hasCapital', 'isPoliticianOf'] [1049, 3061]
# Predicts: wasBornIn [3491] (same_cell)
#
# 0.0114 : isLeaderOf(A, B) -> isCitizenOf(A, B)
# Chain: ['isLeaderOf'] [2749]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.0113 : hasChild(A, B) ^ isLeaderOf(B, C) -> isLeaderOf(A, C)
# Chain: ['hasChild', 'isLeaderOf'] [1151, 2749]
# Predicts: isLeaderOf [2749] (same_cell)
#
# 0.0112 : wroteMusicFor(A, B) -> actedIn(A, B)
# Chain: ['wroteMusicFor'] [3697]
# Predicts: actedIn [3] (same_cell)
#
# 0.0111 : wroteMusicFor(A, B) -> directed(A, B)
# Chain: ['wroteMusicFor'] [3697]
# Predicts: directed [419] (same_cell)
#
# 0.0111 : dealsWith(A, B) -> isLocatedIn(A, B)
# Chain: ['dealsWith'] [211]
# Predicts: isLocatedIn [2851] (same_cell)
#
# 0.0110 : hasChild(A, B) ^ isLeaderOf(B, C) ^ isPoliticianOf(C, D) -> isPoliticianOf(A, D)
# Chain: ['hasChild', 'isLeaderOf', 'isPoliticianOf'] [1151, 2749, 3061]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.0109 : diedIn(A, B) ^ isLocatedIn(B, C) -> isCitizenOf(A, C)
# Chain: ['diedIn', 'isLocatedIn'] [313, 2851]
# Predicts: isCitizenOf [2333] (same_cell)
#
# 0.0109 : participatedIn(A, B) -> participatedIn(A, B)
# Chain: ['participatedIn'] [3373]
# Predicts: participatedIn [3373] (same_cell)
#
# 0.0108 : created(A, B) -> isAffiliatedTo(A, B)
# Chain: ['created'] [107]
# Predicts: isAffiliatedTo [2221] (same_cell)
#
# 0.0104 : created(A, B) ^ hasGender(B, C) -> hasGender(A, C)
# Chain: ['created', 'hasGender'] [107, 1361]
# Predicts: hasGender [1361] (same_cell)
#
# 0.0102 : created(A, B) ^ owns(B, C) -> owns(A, C)
# Chain: ['created', 'owns'] [107, 3271]
# Predicts: owns [3271] (same_cell)
#
# 0.0102 : hasAcademicAdvisor(A, B) ^ influences(B, C) -> hasAcademicAdvisor(A, C)
# Chain: ['hasAcademicAdvisor', 'influences'] [941, 2113]
# Predicts: hasAcademicAdvisor [941] (same_cell)
#
# 0.0100 : isLocatedIn(A, B) ^ livesIn(B, C) -> isPoliticianOf(A, C)
# Chain: ['isLocatedIn', 'livesIn'] [2851, 3163]
# Predicts: isPoliticianOf [3061] (same_cell)
#
# 0.0100 : owns(A, B) ^ worksAt(B, C) -> worksAt(A, C)
# Chain: ['owns', 'worksAt'] [3271, 3593]
# Predicts: worksAt [3593] (same_cell)

# %% [markdown]
# ## Focus on the worksAt relation

# %%
pd.set_option('display.max_colwidth', None)
rules_df[rules_df['Head Rel'] == 'worksAt'].sort_values('Score', ascending=False)
# Out:
#         Score  \
# 28   0.155268
# 30   0.154072
# 31   0.150616
# 64   0.079935
# 115  0.040562
# 122  0.033708
# 171  0.019118
# 197  0.012821
# 224  0.010025
#
#     Head Rel  \
# 28   worksAt
# 30   worksAt
# 31   worksAt
# 64   worksAt
# 115  worksAt
# 122  worksAt
# 171  worksAt
# 197  worksAt
# 224  worksAt
#
#                                                                                 Rule
# 28   graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# 30                         hasAcademicAdvisor(A, B) ^ worksAt(B, C) -> worksAt(A, C)
# 31                                              graduatedFrom(A, B) -> worksAt(A, B)
# 64                   graduatedFrom(A, B) ^ hasAcademicAdvisor(B, C) -> worksAt(A, C)
# 115                                influences(A, B) ^ worksAt(B, C) -> worksAt(A, C)
# 122          graduatedFrom(A, B) ^ influences(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# 171                          graduatedFrom(A, B) ^ influences(B, C) -> worksAt(A, C)
# 197            graduatedFrom(A, B) ^ hasChild(B, C) ^ worksAt(C, D) -> worksAt(A, D)
# 224                                      owns(A, B) ^ worksAt(B, C) -> worksAt(A, C)

# %% [markdown]
# # Conclusion
#
# We show an elegant and fast way of utilizing PAM for rule generation.
#
# The whole procedure takes less than 30 seconds on a commercial laptop and we generate almost 30 thousand rules (for body length up to $k=3$ atoms).
